# %%
import sys
sys.path.append('..')    
import pandas as pd
import numpy as np
from src.data_loader import DataLoader

# Load data
loader = DataLoader(data_dir="../data")
df = pd.read_csv(loader.processed_dir / "raw_data.csv")

# %%
# 1. Basic Information
print("=" * 50)
print("DATASET OVERVIEW")
print("=" * 50)
print(f"Shape: {df.shape}")
print(f"\nColumn info:")
print(df.info())
# Out:
# ...
# DATASET OVERVIEW
# ...
# Shape: (150, 5)
#
# Column info:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 7.2 KB
# None

# %%
# 2. Sample Data
print("\nFirst 5 rows:")
print(df.head())

print("\nLast 5 rows:")
print(df.tail())
# Out:
# First 5 rows:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
#
# Last 5 rows:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# ...

# %%
# 3. Statistical Summary
print("\nStatistical Summary:")
print(df.describe(include='all'))
# Out:
# Statistical Summary:
#         sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count          150.000000        150.000000         150.000000
# unique                NaN               NaN                NaN
# top                   NaN               NaN                NaN
# freq                  NaN               NaN                NaN
# mean             5.843333          3.057333           3.758000
# std              0.828066          0.435866           1.765298
# min              4.300000          2.000000           1.000000
# 25%              5.100000          2.800000           1.600000
# 50%              5.800000          3.000000           4.350000
# 75%              6.400000          3.300000           5.100000
# max              7.900000          4.400000           6.900000
#
#         petal width (cm) species
# count         150.000000     150
# unique               NaN       3
# top                  NaN  setosa
# freq                 NaN      50
# ...

# %%
# 4. Missing Values
print("\nMissing Values:")
print(df.isnull().sum())
print(f"\nTotal missing: {df.isnull().sum().sum()}")
# Out:
# Missing Values:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64
#
# Total missing: 0

# %%
# 5. Data Types
print("\nData Types:")
print(df.dtypes)
# Out:
# Data Types:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# species                  str
# dtype: object

# %%
# 6. Unique Values for Categorical Columns
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
for col in categorical_cols:
    print(f"\nUnique values in {col}: {df[col].unique()}")
# Out:
# Unique values in species: <ArrowStringArray>
# ['setosa', 'versicolor', 'virginica']
# Length: 3, dtype: str
# /var/folders/d3/bxmcbxb11g54bhb7twb2jzcc0000gn/T/ipykernel_3728/3931125275.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = df.select_dtypes(include=['object', 'category']).columns

# %%
# 7. Create data dictionary
dict_df = loader.create_data_dictionary(df)
dict_df.to_csv('../reports/data_dictionary.csv', index=False)
print("\nData dictionary created!")
# Out:
# Data dictionary created!
